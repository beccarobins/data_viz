# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import pandas as pd

df = pd.read_csv 
df.sort_values 
# data_dict = pd.read_excel 
# df.set_index

# %%
df.columns
for col in df.columns:
print 
print
# Out:
# year
# 2018    24956
# 2010    17575
# 2009    16179
# 2013    16089
# 2011    15585
# 2012    14387
# 2014    13980
# 2015    13528
# 2017    12518
# 2016    12217
# 2019     4228
# Name: count, dtype: int64
#
#
# month
# 2     15164
# 1     13861
# 6     13462
# 12    13381
# 8     13333
# 4     13209
# 9     13206
# 11    13199
# 7     13182
# 10    13101
# 3     13095
# 5     13049
# Name: count, dtype: int64
#
#
# carrier
# OO    20751
# EV    17029
# DL    15835
# MQ    12329
# AA    10289
# UA     9944
# WN     9672
# AS     7018
# B6     6809
# F9     6701
# YV     6495
# US     5838
# 9E     5673
# XE     3752
# FL     3731
# OH     2973
# CO     1981
# HA     1962
# NK     1830
# G4     1646
# VX     1428
# YX     1205
# G7     1070
# AX      999
# ZW      975
# NW      858
# PT      790
# QX      580
# C5      500
# CP      474
# EM       62
# KS       28
# 9K       15
# Name: count, dtype: int64
#
#
# carrier_name
# SkyWest Airlines Inc.                        20751
# ...

# %% [markdown]
# ## Basic Bar Chart

# %%
x = df['month'].value_counts .index
y = df['month'].value_counts .values

trace = go.Bar(x=x, y=y,
 marker_color='#9ecae1',
 marker_line_color='#08306b',
 marker_line_width=1.5,
 opacity=0.6,
 # width=0.2
)
layout = go.Layout 
fig = go.Figure 
fig.update_xaxes 
fig.show

# %% [markdown]
# ## Grouped bar chart

# %%
x = ['Female','Male']
y1 = [40,20]
y2 = [30,50]

trace1 = go.Bar 
trace2 = go.Bar 

fig = go.Figure#barmode is as default as grouped
fig.show

# %%
#Stacked/Relative bar chart by re-defining "barmode" in layout
x = ['Female','Male']
y1 = [40,20]
y2 = [30,50]

trace1 = go.Bar 
trace2 = go.Bar 

layout = go.Layout#barmode is changed to stacked

fig = go.Figure 
fig.show

# %%
#100% Stacked bar chart by re-defining "barnorm" as "percent" in layout
x = ['Female','Male']
y1 = [40,20]
y2 = [30,50]

trace1 = go.Bar 
trace2 = go.Bar 

layout = go.Layout#barmode is changed 100% stacked bar chart

fig = go.Figure 
fig.show

# %%
# The yaxis text should be percentage using tickformat
x = ['Female','Male']
y1 = [40,20]
y2 = [30,50]

trace1 = go.Bar 
trace2 = go.Bar 

layout = go.Layout 

fig = go.Figure 
fig.show

# %%
#create your first scatter plot

x = [1,2,3,4,5]
y = [10,22,34,40,50]

trace1 = go.Scatter 

fig = go.Figure 
fig.show

# %%
#style the markers
x = [1,2,3,4,5]
y = [10,22,34,40,50]

trace1= go.Scatter 

fig = go.Figure 
fig.show

# %%
# Assign color according to values in colorscale
# "Colorscale" options: Greys,YlGnBu,Greens,YlOrRd,Bluered,RdBu,Reds,Blues,Picnic,Rainbow,Portland,Jet,Hot,Blackbody,Earth,Electric,Viridis,Cividis
# Title and names for axes
x = [1,2,3,4,5]
y = [10,22,34,40,50]

trace1 = go.Scatter(x=x, 
 y=y, 
 mode='markers',
 marker={'size': 10,'color':x,'colorscale':'Rainbow'})

layout=go.Layout 

fig = go.Figure 
fig.show

# %%
#try plotting scatters in a 3D space
x = [1,2,3,4,5]
y = [10,22,34,40,50]
z = [2,3,4,5,6]

trace1= go.Scatter3d(x=x,
 y=y,
 z=z,
 mode='markers')

layout= go.Layout(scene={'xaxis':{'title':'length'},
 'yaxis':{'title':'width'},
 'zaxis':{'title':'height'}})

fig = go.Figure 
fig.show

# %%
# Create scatter plot object, but add color and size parameters to the 'marker' dictionary
x = [1,2,3,4,5]
y = [10,22,34,40,50]

trace1 = go.Scatter 

fig = go.Figure 
fig.show

# %%
# Create scatter plot object, but add color and size parameters to the 'marker' dictionary
trace0 = go.Scatter(
x=[1, 1.5, 1.48, 1.75, 1.85, 1.95, 2, 2.25, 2.25, 2.28, 2.5, 2.5, 3],
y=[12, 12, 12.3, 13, 12.1, 12.2, 12, 11.5, 12.5, 12.25, 11.2, 11.5, 13.5],

mode='markers',
marker=dict(
color=['rgb ',
 'rgb ',
 'rgb ',
 'rgb ',
 'rgb ',
 'rgb ',
 'rgb '],
size=[20, 50, 35, 40, 45, 40, 45, 50, 55, 60, 40, 60, 10],
)
)

# Visualize plot
fig = go.Figure 
fig.show

# %%
import plotly
print
# Out:
# 5.22.0

# %%
map_data = dict(type = 'choropleth',
locations = ['MI', 'CO', 'FL', 'IN'],
locationmode = 'USA-states',
colorscale = 'RdBu',
text = ['Michigan', 'Colorado', 'Florida', 'Indiana'],
z = [1.0, 2.0, 3.0, 4.0],
colorbar = dict 
 )
layout = go.Layout 
fig = go.Figure 
fig.show

# %%
us_state_abbrev = {
'Alabama': 'AL',
'Alaska': 'AK',
'Arizona': 'AZ',
'Arkansas': 'AR',
'California': 'CA',
'Colorado': 'CO',
'Connecticut': 'CT',
'Delaware': 'DE',
'Florida': 'FL',
'Georgia': 'GA',
'Hawaii': 'HI',
'Idaho': 'ID',
'Illinois': 'IL',
'Indiana': 'IN',
'Iowa': 'IA',
'Kansas': 'KS',
'Kentucky': 'KY',
'Louisiana': 'LA',
'Maine': 'ME',
'Maryland': 'MD',
'Massachusetts': 'MA',
'Michigan': 'MI',
'Minnesota': 'MN',
'Mississippi': 'MS',
'Missouri': 'MO',
'Montana': 'MT',
'Nebraska': 'NE',
'Nevada': 'NV',
'New Hampshire': 'NH',
'New Jersey': 'NJ',
'New Mexico': 'NM',
'New York': 'NY',
'North Carolina': 'NC',
'North Dakota': 'ND',
'Ohio': 'OH',
'Oklahoma': 'OK',
'Oregon': 'OR',
'Pennsylvania': 'PA',
'Rhode Island': 'RI',
'South Carolina': 'SC',
'South Dakota': 'SD',
'Tennessee': 'TN',
'Texas': 'TX',
'Utah': 'UT',
'Vermont': 'VT',
'Virginia': 'VA',
'Washington': 'WA',
'West Virginia': 'WV',
'Wisconsin': 'WI',
'Wyoming': 'WY',
}

# %%
df
# Out:
#         year  month carrier                 carrier_name airport  \
# 159765  2009      2      9E       Pinnacle Airlines Inc.     ABE
# 159766  2009      2      9E       Pinnacle Airlines Inc.     ALB
# 159767  2009      2      9E       Pinnacle Airlines Inc.     ALO
# 159768  2009      2      9E       Pinnacle Airlines Inc.     ATL
# 159769  2009      2      9E       Pinnacle Airlines Inc.     ATW
# ...      ...    ...     ...                          ...     ...
# 2084    2019      2      ZW  Air Wisconsin Airlines Corp     STL
# 2085    2019      2      ZW  Air Wisconsin Airlines Corp     SYR
# 2086    2019      2      ZW  Air Wisconsin Airlines Corp     TUL
# 2087    2019      2      ZW  Air Wisconsin Airlines Corp     TVC
# 2088    2019      2      ZW  Air Wisconsin Airlines Corp     TYS
#
#                                              airport_name  arr_flights  \
# 159765  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         76.0
# ...

# %%
df['arr_delay'].dtype
# Out:
# dtype('float64')

# %%
df.groupby('abbrev')['arr_delay'].sum()
# Out:
# abbrev
# Alabama            3999604.0
# Alaska             2684138.0
# Arizona           15914448.0
# Arkansas           2064698.0
# California        78601335.0
# Colorado          27201270.0
# Connecticut        2637128.0
# Delaware             24818.0
# Florida           51148843.0
# Georgia           44227268.0
# Hawaii             6549095.0
# Idaho              1792838.0
# Illinois           9284233.0
# Indiana            5289038.0
# Iowa               2403634.0
# Kansas             1504741.0
# Kentucky           2856099.0
# Louisiana          7269726.0
# Maine              1141823.0
# Maryland           9499696.0
# Massachusetts     15665608.0
# Michigan          16970677.0
# Minnesota         13232144.0
# Mississippi        1669994.0
# Missouri          11689422.0
# Montana            1217469.0
# Nebraska           2792022.0
# Nevada             3352069.0
# New Hampshire       145532.0
# New Jersey        23739506.0
# New Mexico         2653781.0
# ...

# %%
df.groupby('abbrev')['arr_delay'].sum().median()
# Out:
# 5289038.0

# %%
df.groupby('abbrev')['arr_delay'].sum().min()
# Out:
# 24818.0

# %%
df['abbrev'] = df['airport_name'].map(airports)

map_data = dict(type='choropleth',  
                locations=df.groupby('abbrev')['arr_delay'].count().index,
                locationmode='USA-states',
                text=df.groupby('abbrev')['arr_delay'].count().index,
                # marker=dict(line=dict(color='rgb(255,0,0)', width=0.5)),
                z=df.groupby('abbrev')['arr_delay'].sum(),
           )
layout = dict(
        # title = 'USA States GDP Per Capita - 2017',  
              geo = dict(scope='usa')
             )
fig = go.Figure(map_data, layout)
# fig.update_geos(fitbounds="locations")
fig.show()

# %%
airports = {
'Mobile, AL: Mobile International': 'Alabama',
'Birmingham, AL: Birmingham-Shuttlesworth International': 'Alabama',
'Dothan, AL: Dothan Regional': 'Alabama',
'Gulf Shores, AL: Gulf Shores International Jack Edwards Field': 'Alabama',
'Huntsville, AL: Huntsville International-Carl T Jones Field': 'Alabama',
'Montgomery, AL: Montgomery Regional': 'Alabama',
'Mobile, AL: Mobile Regional': 'Alabama',
'Adak Island, AK: Adak' : 'Alaska',
'Kodiak, AK: Kodiak Airport' : 'Alaska',
'King Salmon, AK: King Salmon Airport' : 'Alaska',
'Anchorage, AK: Ted Stevens Anchorage International' : 'Alaska',
'Bethel, AK: Bethel Airport' : 'Alaska',
'Barrow, AK: Wiley Post/Will Rogers Memorial' : 'Alaska',
'Cold Bay, AK: Cold Bay Airport' : 'Alaska',
'Cordova, AK: Merle K Mudhole Smith' : 'Alaska',
'Dillingham, AK: Dillingham Airport' : 'Alaska',
'Unalaska, AK: Unalaska Airport' : 'Alaska',
'Fairbanks, AK: Fairbanks International' : 'Alaska',
'Gustavus, AK: Gustavus Airport' : 'Alaska',
'Juneau, AK: Juneau International' : 'Alaska',
'Ketchikan, AK: Ketchikan International' : 'Alaska',
'Nome, AK: Nome Airport' : 'Alaska',
'Kotzebue, AK: Ralph Wien Memorial' : 'Alaska',
'Petersburg, AK: Petersburg James A Johnson' : 'Alaska',
'Deadhorse, AK: Deadhorse Airport': 'Alaska',
'Sitka, AK: Sitka Rocky Gutierrez': 'Alaska',
'Wrangell, AK: Wrangell Airport': 'Alaska',
'Yakutat, AK: Yakutat Airport': 'Alaska',
'Phoenix, AZ: Mesa Gateway': 'Arizona',
'Flagstaff, AZ: Flagstaff Pulliam': 'Arizona',
'Bullhead City, AZ: Laughlin/Bullhead International': 'Arizona',
'Phoenix, AZ: Phoenix Sky Harbor International': 'Arizona',
'Prescott, AZ: Prescott Regional Ernest A Love Field': 'Arizona',
'Tucson, AZ: Tucson International': 'Arizona',
'Yuma, AZ: Yuma MCAS/Yuma International': 'Arizona',
'Fort Smith, AR: Fort Smith Regional': 'Arkansas',
'Little Rock, AR: Bill and Hillary Clinton Nat Adams Field': 'Arkansas',
'Texarkana, AR: Texarkana Regional-Webb Field': 'Arkansas',
'Fayetteville, AR: Northwest Arkansas National': 'Arkansas',
'Arcata/Eureka, CA: California Redwood Coast Humboldt County': 'California',
'Bakersfield, CA: Meadows Field': 'California',
'Bishop, CA: Bishop Airport': 'California',
'Burbank, CA: Bob Hope': 'California',
'Crescent City, CA: Jack McNamara Field': 'California',
'Chico, CA: Chico Regional': 'California',
'Carlsbad, CA: McClellan-Palomar': 'California',
'Fresno, CA: Fresno Yosemite International': 'California',
'El Centro, CA: Imperial County': 'California',
'Inyokern, CA: Inyokern Airport': 'California',
'Los Angeles, CA: Los Angeles International': 'California',
'Long Beach, CA: Long Beach Airport': 'California',
'Mammoth Lakes, CA: Mammoth Lakes Airport': 'California',
'Modesto, CA: Modesto City-County-Harry Sham Field': 'California',
'Monterey, CA: Monterey Regional': 'California',
'Oakland, CA: Oakland International': 'California',
'Ontario, CA: Ontario International': 'California',
'Oxnard/Ventura, CA: Oxnard': 'California',
'Palmdale, CA: Palmdale USAF Plant 42': 'California',
'Palm Springs, CA: Palm Springs International': 'California',
'Redding, CA: Redding Regional': 'California',
'San Diego, CA: San Diego International': 'California',
'San Luis Obispo, CA: San Luis Obispo County Regional': 'California',
'Stockton, CA: Stockton Metro': 'California',
'San Francisco, CA: San Francisco International': 'California',
'San Jose, CA: Norman Y. Mineta San Jose International': 'California',
'Sacramento, CA: Sacramento International': 'California',
'Santa Maria, CA: Santa Maria Public/Capt. G. Allan Hancock Field': 'California',
'Santa Ana, CA: John Wayne Airport-Orange County': 'California',
'Santa Rosa, CA: Charles M. Schulz - Sonoma County': 'California',
'Visalia, CA: Visalia Municipal': 'California',
'Alamosa, CO: San Luis Valley Regional/Bergman Field': 'Colorado',
'Aspen, CO: Aspen Pitkin County Sardy Field': 'Colorado',
'Colorado Springs, CO: City of Colorado Springs Municipal': 'Colorado',
'Denver, CO: Denver International': 'Colorado',
'Durango, CO: Durango La Plata County': 'Colorado',
'Eagle, CO: Eagle County Regional': 'Colorado',
'Fort Collins/Loveland, CO: Northern Colorado Regional': 'Colorado',
'Grand Junction, CO: Grand Junction Regional': 'Colorado',
'Gunnison, CO: Gunnison-Crested Butte Regional': 'Colorado',
'Hayden, CO: Yampa Valley': 'Colorado',
'Montrose/Delta, CO: Montrose Regional': 'Colorado',
'Pueblo, CO: Pueblo Memorial': 'Colorado',
'Telluride, CO: Telluride Regional': 'Colorado',
'Hartford, CT: Bradley International': 'Connecticut',
'New Haven, CT: Tweed New Haven': 'Connecticut',
'Wilmington, DE: New Castle': 'Delaware',
'Naples, FL: Naples Municipal': 'Florida',
'Daytona Beach, FL: Daytona Beach International': 'Florida',
'Panama City, FL: Northwest Florida Beaches International': 'Florida',
'Key West, FL: Key West International': 'Florida',
'Fort Lauderdale, FL: Fort Lauderdale-Hollywood International': 'Florida',
'Gainesville, FL: Gainesville Regional': 'Florida',
'Jacksonville, FL: Jacksonville International': 'Florida',
'Orlando, FL: Orlando International': 'Florida',
'Miami, FL: Miami International': 'Florida',
'Melbourne, FL: Melbourne Orlando International': 'Florida',
'Marathon, FL: The Florida Keys Marathon International': 'Florida',
'West Palm Beach/Palm Beach, FL: Palm Beach International': 'Florida',
'Panama City, FL: Bay County': 'Florida',
'Punta Gorda, FL: Punta Gorda Airport': 'Florida',
'St. Petersburg, FL: St Pete Clearwater International': 'Florida',
'Pensacola, FL: Pensacola International': 'Florida',
'Fort Myers, FL: Southwest Florida International': 'Florida',
'Sanford, FL: Orlando Sanford International': 'Florida',
'Sarasota/Bradenton, FL: Sarasota/Bradenton International': 'Florida',
'Tallahassee, FL: Tallahassee International': 'Florida',
'Tampa, FL: Tampa International': 'Florida',
'St. Augustine, FL: Northeast Florida Regional': 'Florida',
'Valparaiso, FL: Eglin AFB Destin Fort Walton Beach': 'Florida',
'Albany, GA: Southwest Georgia Regional': 'Georgia',
'Augusta, GA: Augusta Regional at Bush Field': 'Georgia',
'Atlanta, GA: Hartsfield-Jackson Atlanta International': 'Georgia',
'Brunswick, GA: Brunswick Golden Isles': 'Georgia',
'Columbus, GA: Columbus Airport': 'Georgia',
'Macon, GA: Middle Georgia Regional': 'Georgia',
'Savannah, GA: Savannah/Hilton Head International': 'Georgia',
'Valdosta, GA: Valdosta Regional': 'Georgia',
'Honolulu, HI: Daniel K Inouye International': 'Hawaii',
'Hilo, HI: Hilo International': 'Hawaii',
'Kapalua, HI: Kapalua Airport	': 'Hawaii',
'Kona, HI: Ellison Onizuka Kona International at Keahole': 'Hawaii',
'Lihue, HI: Lihue Airport': 'Hawaii',
'Lanai, HI: Lanai Airport': 'Hawaii',
'Hoolehua, HI: Molokai': 'Hawaii',
'Kahului, HI: Kahului Airport': 'Hawaii',
'Boise, ID: Boise Air Terminal': 'Idaho',
'Idaho Falls, ID: Idaho Falls Regional': 'Idaho',
'Lewiston, ID: Lewiston Nez Perce County': 'Idaho',
'Pocatello, ID: Pocatello Regional': 'Idaho',
'Sun Valley/Hailey/Ketchum, ID: Friedman Memorial': 'Idaho',
'Twin Falls, ID: Joslin Field - Magic Valley Regional': 'Idaho',
'Belleville, IL: Scott AFB MidAmerica St Louis': 'Illinois',
'Bloomington/Normal, IL: Central Il Regional Airport at Bloomington': 'Illinois',
'Champaign/Urbana, IL: University of Illinois/Willard': 'Illinois',
'Decatur, IL: Decatur Airport': 'Illinois',
'Chicago, IL: Chicago Midway International': 'Illinois',
'Moline, IL: Quad Cities International': 'Illinois',
'Chicago, IL: Chicago O’Hare International': 'Illinois',
'Peoria, IL: General Downing - Peoria International': 'Illinois',
'Rockford, IL: Chicago/Rockford International': 'Illinois',
'Springfield, IL: Abraham Lincoln Capital': 'Illinois',
'Quincy, IL: Quincy Regional-Baldwin Field': 'Illinois',
'Evansville, IN: Evansville Regional': 'Indiana',
'Fort Wayne, IN: Fort Wayne International': 'Indiana',
'Indianapolis, IN: Indianapolis International': 'Indiana',
'Lafayette, IN: Purdue University': 'Indiana',
'South Bend, IN: South Bend International': 'Indiana',
'Waterloo, IA: Waterloo Regional': 'Iowa',
'Cedar Rapids/Iowa City, IA: The Eastern Iowa': 'Iowa',
'Dubuque, IA: Dubuque Regional': 'Iowa',
'Des Moines, IA: Des Moines International': 'Iowa',
'Fort Dodge, IA: Fort Dodge Regional': 'Iowa',
'Mason City, IA: Mason City Municipal': 'Iowa',
'Sioux City, IA: Sioux Gateway Brig Gen Bud Day Field': 'Iowa',
'Dodge City, KS: Dodge City Regional': 'Kansas',
'Topeka, KS: Topeka Regional': 'Kansas',
'Garden City, KS: Garden City Regional': 'Kansas',
'Hays, KS: Hays Regional': 'Kansas',
'Wichita, KS: Wichita Dwight D Eisenhower National': 'Kansas',
'Liberal, KS: Liberal Mid-America Regional': 'Kansas',
'Manhattan/Ft. Riley, KS: Manhattan Regional': 'Kansas',
'Salina, KS: Salina Regional': 'Kansas',
'Lexington, KY: Blue Grass': 'Kentucky',
'Owensboro, KY: Owensboro Daviess County Regional': 'Kentucky',
'Paducah, KY: Barkley Regional': 'Kentucky',
'Louisville, KY: Louisville Muhammad Ali International': 'Kentucky',
'Alexandria, LA: Alexandria International': 'Louisiana',
'Baton Rouge, LA: Baton Rouge Metropolitan/Ryan Field': 'Louisiana',
'Lake Charles, LA: Lake Charles Regional': 'Louisiana',
'Lafayette, LA: Lafayette Regional Paul Fournet Field': 'Louisiana',
'Monroe, LA: Monroe Regional': 'Louisiana',
'New Orleans, LA: Louis Armstrong New Orleans International': 'Louisiana',
'Shreveport, LA: Shreveport Regional': 'Louisiana',
'Bangor, ME: Bangor International': 'Maine',
'Presque Isle/Houlton, ME: Presque Isle International': 'Maine',
'Portland, ME: Portland International Jetport': 'Maine',
'Baltimore, MD: Baltimore/Washington International Thurgood Marshall': 'Maryland',
'Hagerstown, MD: Hagerstown Regional-Richard A. Henson Field': 'Maryland',
'Salisbury, MD: Salisbury-Ocean City/Wicomico Regional': 'Maryland',
'Nantucket, MA: Nantucket Memorial': 'Massachusetts',
'Boston, MA: Logan International': 'Massachusetts',
'Hyannis, MA: Cape Cod Gateway': 'Massachusetts',
'Martha’s Vineyard, MA: Martha’s Vineyard Airport': 'Massachusetts',
'Worcester, MA: Worcester Regional': 'Massachusetts',
'Alpena, MI: Alpena County Regional': 'Michigan',
'Kalamazoo, MI: Kalamazoo/Battle Creek International': 'Michigan',
'Sault Ste. Marie, MI: Chippewa County International': 'Michigan',
'Hancock/Houghton, MI: Houghton County Memorial': 'Michigan',
'Detroit, MI: Detroit Metro Wayne County': 'Michigan',
'Escanaba, MI: Delta County': 'Michigan',
'Flint, MI: Bishop International': 'Michigan',
'Grand Rapids, MI: Gerald R. Ford International': 'Michigan',
'Iron Mountain/Kingsfd, MI: Ford': 'Michigan',
'Lansing, MI: Capital Region International': 'Michigan',
'Saginaw/Bay City/Midland, MI: MBS International': 'Michigan',
'Muskegon, MI: Muskegon County': 'Michigan',
'Marquette, MI: Marquette Sawyer Regional': 'Michigan',
'Pellston, MI: Pellston Regional Emmet County': 'Michigan',
'Traverse City, MI: Cherry Capital': 'Michigan',
'Bemidji, MN: Bemidji Regional': 'Minnesota',
'Brainerd, MN: Brainerd Lakes Regional': 'Minnesota',
'Duluth, MN: Duluth International': 'Minnesota',
'Hibbing, MN: Range Regional': 'Minnesota',
'International Falls, MN: Falls International Einarson Field': 'Minnesota',
'Minneapolis, MN: Minneapolis-St Paul International': 'Minnesota',
'Rochester, MN: Rochester International': 'Minnesota',
'St. Cloud, MN: St. Cloud Regional': 'Minnesota',
'Columbus, MS: Columbus AFB': 'Mississippi',
'Greenville, MS: Greenville Mid Delta': 'Mississippi',
'Gulfport/Biloxi, MS: Gulfport-Biloxi International': 'Mississippi',
'Columbus, MS: Golden Triangle Regional': 'Mississippi',
'Jackson/Vicksburg, MS: Jackson Medgar Wiley Evers International': 'Mississippi',
'Meridian, MS: Key Field': 'Mississippi',
'Hattiesburg/Laurel, MS: Hattiesburg-Laurel Regional': 'Mississippi',
'Tupelo, MS: Tupelo Regional': 'Mississippi',
'Tunica, MS: Tunica Municipal': 'Mississippi',
'Branson, MO: Branson Airport': 'Missouri',
'Cape Girardeau, MO: Cape Girardeau Regional': 'Missouri',
'Columbia, MO: Columbia Regional': 'Missouri',
'Joplin, MO: Joplin Regional': 'Missouri',
'Kansas City, MO: Kansas City International': 'Missouri',
'Kansas City, MO: Kansas City Downtown Wheeler Field': 'Missouri',
'Springfield, MO: Springfield-Branson National': 'Missouri',
'St. Louis, MO: St Louis Lambert International': 'Missouri',
'Fort Leonard Wood, MO: Waynesville-St. Robert Regional Forney Field': 'Missouri',
'Billings, MT: Billings Logan International': 'Montana',
'Butte, MT: Bert Mooney': 'Montana',
'Bozeman, MT: Bozeman Yellowstone International': 'Montana',
'Kalispell, MT: Glacier Park International': 'Montana',
'Great Falls, MT: Great Falls International': 'Montana',
'Helena, MT: Helena Regional': 'Montana',
'Missoula, MT: Missoula Montana': 'Montana',
'West Yellowstone, MT: Yellowstone': 'Montana',
'Scottsbluff, NE: Scottsbluff W Neb Regional Wm B Heilig Field': 'Nebraska',
'Kearney, NE: Kearney Regional': 'Nebraska',
'Grand Island, NE: Central Nebraska Regional': 'Nebraska',
'Lincoln, NE: Lincoln Airport': 'Nebraska',
'Omaha, NE: Eppley Airfield': 'Nebraska',
'Elko, NV: Elko Regional': 'Nevada',
'Las Vegas, NV: Harry Reid International': 'Nevada',
'Reno, NV: Reno/Tahoe International': 'Nevada',
'Manchester, NH: Manchester Boston Regional': 'New Hampshire',
'Portsmouth, NH: Portsmouth International at Pease': 'New Hampshire',
'Atlantic City, NJ: Atlantic City International': 'New Jersey',
'Newark, NJ: Newark Liberty International': 'New Jersey',
'Trenton, NJ: Trenton Mercer': 'New Jersey',
'Albuquerque, NM: Albuquerque International Sunport': 'New Mexico',
'Farmington, NM: Four Corners Regional': 'New Mexico',
'Hobbs, NM: Lea County Regional': 'New Mexico',
'Roswell, NM: Roswell Air Center': 'New Mexico',
'Santa Fe, NM: Santa Fe Regional': 'New Mexico',
'Albany, NY: Albany International': 'New York',
'Watertown, NY: Watertown International': 'New York',
'Binghamton, NY: Greater Binghamton/Edwin A. Link Field': 'New York',
'Buffalo, NY: Buffalo Niagara International': 'New York',
'Elmira/Corning, NY: Elmira/Corning Regional': 'New York',
'White Plains, NY: Westchester County': 'New York',
'Niagara Falls, NY: Niagara Falls International': 'New York',
'Islip, NY: Long Island MacArthur': 'New York',
'Ithaca/Cortland, NY: Ithaca Tompkins International': 'New York',
'New York, NY: John F. Kennedy International': 'New York',
'New York, NY: LaGuardia': 'New York',
'Ogdensburg, NY: Ogdensburg International': 'New York',
'Plattsburgh, NY: Plattsburgh International': 'New York',
'Rochester, NY: Frederick Douglass Grtr Rochester International': 'New York',
'Newburgh/Poughkeepsie, NY: New York Stewart International': 'New York',
'Syracuse, NY: Syracuse Hancock International': 'New York',
'Asheville, NC: Asheville Regional': 'North Carolina',
'Charlotte, NC: Charlotte Douglas International': 'North Carolina',
'New Bern/Morehead/Beaufort, NC: Coastal Carolina Regional': 'North Carolina',
'Fayetteville, NC: Fayetteville Regional/Grannis Field': 'North Carolina',
'Greensboro/High Point, NC: Piedmont Triad International': 'North Carolina',
'Hickory, NC: Hickory Regional': 'North Carolina',
'Wilmington, NC: Wilmington International': 'North Carolina',
'Kinston, NC: Kinston Regional Jetport at Stallings Field': 'North Carolina',
'Jacksonville/Camp Lejeune, NC: Albert J Ellis': 'North Carolina',
'Greenville, NC: Pitt Greenville': 'North Carolina',
'Raleigh/Durham, NC: Raleigh-Durham International': 'North Carolina',
'Pinehurst/Southern Pines, NC: Moore County': 'North Carolina',
'Concord, NC: Concord Padgett Regional': 'North Carolina',
'Bismarck/Mandan, ND: Bismarck Municipal': 'North Dakota',
'Dickinson, ND: Dickinson - Theodore Roosevelt Regional': 'North Dakota',
'Devils Lake, ND: Devils Lake Regional': 'North Dakota',
'Fargo, ND: Hector International': 'North Dakota',
'Grand Forks, ND: Grand Forks International': 'North Dakota',
'Williston, ND: Sloulin Field International': 'North Dakota',
'Jamestown, ND: Jamestown Regional': 'North Dakota',
'Minot, ND: Minot International': 'North Dakota',
'Williston, ND: Williston Basin International': 'North Dakota',
'Akron, OH: Akron-Canton Regional': 'Ohio',
'Cleveland, OH: Cleveland-Hopkins International': 'Ohio',
'Columbus, OH: John Glenn Columbus International': 'Ohio',
'Cincinnati, OH: Cincinnati/Northern Kentucky International': 'Ohio',
'Dayton, OH: James M Cox/Dayton International': 'Ohio',
'Columbus, OH: Rickenbacker International': 'Ohio',
'Toledo, OH: Eugene F Kranz Toledo Express': 'Ohio',
'Youngstown/Warren, OH: Youngstown-Warren Regional': 'Ohio',
'Lawton/Fort Sill, OK: Lawton-Fort Sill Regional': 'Oklahoma',
'Oklahoma City, OK: Okc Will Rogers International': 'Oklahoma',
'Stillwater, OK: Stillwater Regional': 'Oklahoma',
'Tulsa, OK: Tulsa International': 'Oklahoma',
'Eugene, OR: Mahlon Sweet Field': 'Oregon',
'Klamath Falls, OR: Crater Lake Klamath Regional': 'Oregon',
'Medford, OR: Rogue Valley International - Medford': 'Oregon',
'North Bend/Coos Bay, OR: Southwest Oregon Regional': 'Oregon',
'Portland, OR: Portland International': 'Oregon',
'Bend/Redmond, OR: Roberts Field': 'Oregon',
'Salem, OR: McNary Field': 'Oregon',
'Allentown/Bethlehem/Easton, PA: Lehigh Valley International': 'Pennsylvania',
'Scranton/Wilkes-Barre, PA: Wilkes Barre Scranton International': 'Pennsylvania',
'Erie, PA: Erie International/Tom Ridge Field': 'Pennsylvania',
'Williamsport, PA: Williamsport Regional': 'Pennsylvania',
'Johnstown, PA: John Murtha Johnstown-Cambria County': 'Pennsylvania',
'Latrobe, PA: Arnold Palmer Regional': 'Pennsylvania',
'Harrisburg, PA: Harrisburg International': 'Pennsylvania',
'Philadelphia, PA: Philadelphia International': 'Pennsylvania',
'Pittsburgh, PA: Pittsburgh International': 'Pennsylvania',
'State College, PA: State College Regional': 'Pennsylvania',
'Providence, RI: Rhode Island Tf Green International': 'Rhode Island',
'Columbia, SC: Columbia Metropolitan': 'South Carolina',
'Charleston, SC: Charleston AFB/International': 'South Carolina',
'Florence, SC: Florence Regional': 'South Carolina',
'Greer, SC: Greenville-Spartanburg International': 'South Carolina',
'Hilton Head, SC: Hilton Head Airport': 'South Carolina',
'Myrtle Beach, SC: Myrtle Beach International': 'South Carolina',
'Aberdeen, SD: Aberdeen Regional': 'South Dakota',
'Watertown, SD: Watertown Regional': 'South Dakota',
'Sioux Falls, SD: Joe Foss Field': 'South Dakota',
'Pierre, SD: Pierre Regional': 'South Dakota',
'Rapid City, SD: Rapid City Regional': 'South Dakota',
'Rapid City, SD: Ellsworth AFB': 'South Dakota',
'Nashville, TN: Nashville International': 'Tennessee',
'Chattanooga, TN: Lovell Field': 'Tennessee',
'Memphis, TN: Memphis International': 'Tennessee',
'Bristol/Johnson City/Kingsport, TN: Tri Cities': 'Tennessee',
'Knoxville, TN: McGhee Tyson': 'Tennessee',
'Abilene, TX: Abilene Regional': 'Texas',
'Waco, TX: Waco Regional': 'Texas',
'Amarillo, TX: Rick Husband Amarillo International': 'Texas',
'Austin, TX: Austin - Bergstrom International': 'Texas',
'Beaumont/Port Arthur, TX: Jack Brooks Regional': 'Texas',
'Brownsville, TX: Brownsville South Padre Island International': 'Texas',
'College Station/Bryan, TX: Easterwood Field': 'Texas',
'Corpus Christi, TX: Corpus Christi International': 'Texas',
'Dallas, TX: Dallas Love Field': 'Texas',
'Dallas/Fort Worth, TX: Dallas/Fort Worth International': 'Texas',
'Del Rio, TX: Del Rio International': 'Texas',
'Houston, TX: Ellington': 'Texas',
'El Paso, TX: El Paso International': 'Texas',
'Longview, TX: East Texas Regional': 'Texas',
'Killeen, TX: Robert Gray AAF': 'Texas',
'Harlingen/San Benito, TX: Valley International': 'Texas',
'Houston, TX: George Bush Intercontinental/Houston': 'Texas',
'Killeen, TX: Skylark Field': 'Texas',
'Lubbock, TX: Lubbock Preston Smith International': 'Texas',
'Laredo, TX: Laredo International': 'Texas',
'Midland/Odessa, TX: Midland International Air and Space Port': 'Texas',
'Mission/McAllen/Edinburg, TX: McAllen International': 'Texas',
'San Antonio, TX: San Antonio International': 'Texas',
'San Angelo, TX: San Angelo Regional/Mathis Field': 'Texas',
'Wichita Falls, TX: Sheppard AFB/Wichita Falls Municipal': 'Texas',
'Tyler, TX: Tyler Pounds Regional': 'Texas',
'Victoria, TX: Victoria Regional': 'Texas',
'Cedar City, UT: Cedar City Regional': 'Utah',
'Moab, UT: Canyonlands Regional': 'Utah',
'Ogden, UT: Ogden-Hinckley': 'Utah',
'Provo, UT: Provo Municipal': 'Utah',
'St. George, UT: St George Regional': 'Utah',
'Salt Lake City, UT: Salt Lake City International': 'Utah',
'Vernal, UT: Vernal Regional': 'Utah',
'Burlington, VT: Patrick Leahy Burlington International': 'Vermont',
'Charlottesville, VA: Charlottesville Albemarle': 'Virginia',
'Lynchburg, VA: Lynchburg Regional/Preston Glenn Field': 'Virginia',
'Norfolk, VA: Norfolk International': 'Virginia',
'Newport News/Williamsburg, VA: Newport News/Williamsburg International': 'Virginia',
'Richmond, VA: Richmond International': 'Virginia',
'Roanoke, VA: Roanoke Blacksburg Regional': 'Virginia',
'Staunton, VA: Shenandoah Valley Regional': 'Virginia',
'Walla Walla, WA: Walla Walla Regional': 'Washington',
'Bellingham, WA: Bellingham International': 'Washington',
'Wenatchee, WA: Pangborn Memorial': 'Washington',
'Spokane, WA: Spokane International': 'Washington',
'Moses Lake, WA: Grant County International': 'Washington',
'Everett, WA: Seattle Paine Field International': 'Washington',
'Pasco/Kennewick/Richland, WA: Tri Cities': 'Washington',
'Pullman, WA: Pullman Moscow Regional': 'Washington',
'Seattle, WA: Seattle/Tacoma International': 'Washington',
'Spokane, WA: Fairchild AFB': 'Washington',
'Yakima, WA: Yakima Air Terminal/McAllister Field': 'Washington',
'Clarksburg/Fairmont, WV: North Central West Virginia': 'West Virginia',
'Charleston/Dunbar, WV: West Virginia International Yeager': 'West Virginia',
'Ashland, WV: Tri-State/Milton J. Ferguson Field': 'West Virginia',
'Lewisburg, WV: Greenbrier Valley': 'West Virginia',
'Morgantown, WV: Morgantown Municipal Walter L Bill Hart Field': 'West Virginia',
'Appleton, WI: Appleton International': 'Wisconsin',
'Mosinee, WI: Central Wisconsin': 'Wisconsin',
'Eau Claire, WI: Chippewa Valley Regional': 'Wisconsin',
'Green Bay, WI: Green Bay Austin Straubel International': 'Wisconsin',
'La Crosse, WI: La Crosse Regional': 'Wisconsin',
'Milwaukee, WI: General Mitchell International': 'Wisconsin',
'Madison, WI: Dane County Regional-Truax Field': 'Wisconsin',
'Rhinelander, WI: Rhinelander/Oneida County': 'Wisconsin',
'Cody, WY: Yellowstone Regional': 'Wyoming',
'Casper, WY: Casper/Natrona County International': 'Wyoming',
'Cheyenne, WY: Cheyenne Regional/Jerry Olson Field': 'Wyoming',
'Gillette, WY: Northeast Wyoming Regional': 'Wyoming',
'Jackson, WY: Jackson Hole': 'Wyoming',
'Laramie, WY: Laramie Regional': 'Wyoming',
'Riverton/Lander, WY: Central Wyoming Regional': 'Wyoming',
'Rock Springs, WY: Southwest Wyoming Regional': 'Wyoming',
'Sheridan, WY: Sheridan County': 'Wyoming'}

# %%
data = [go.Choropleth(
                    locations=df.groupby('abbrev')['arr_delay'].count().index,
                locationmode='USA-states',
    # locations = merge_df['CODE'],
    z = df.groupby('abbrev')['arr_delay'].count().values,
    text = df.groupby('abbrev')['arr_delay'].count().index,
    colorscale = [
        [0, "rgb(255,255,204)"],
        [0.35, "rgb(217,240,163)"],
        [0.5, "rgb(173,221,142)"],
        [0.6, "rgb(120,198,121)"],
        [0.7, "rgb(49,163,84)"],
        [1, "rgb(0,104,55)"]],
    marker = go.choropleth.Marker(line = go.choropleth.marker.Line(
                                  color = 'rgb(180,180,180)',
                                  width = 0.5)),
    colorbar = go.choropleth.ColorBar(title = 'Happiness Score'),
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Happiness Around the World - 2018'
    ),
    geo = go.layout.Geo(showframe = False, # If this key is set to False, the resultant plot does not contain a boundary.
                        showcoastlines = False,
                        projection = go.layout.geo.Projection(
                        type = 'equirectangular'
        )
    ),
    annotations = [go.layout.Annotation(
        x = 0.55,
        y = 0.05,
        text = 'Finland is at the happinest country with a score 7.63 while Burundi is the less with a score of 2.91.'
    )]
)
fig = go.Figure(data = data, layout = layout)
fig.show()
